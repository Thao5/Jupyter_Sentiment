# %%
# %pip install -r requirements.txt
# Out:
# Collecting en-core-web-sm@ https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (from -r requirements.txt (line 18))
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#                                               0.0/12.8 MB ? eta -:--:--
#                                               0.0/12.8 MB 1.3 MB/s eta 0:00:10
#                                               0.1/12.8 MB 1.2 MB/s eta 0:00:11
#                                               0.3/12.8 MB 2.0 MB/s eta 0:00:07
#      -                                        0.5/12.8 MB 3.0 MB/s eta 0:00:05
#      --                                       0.9/12.8 MB 4.3 MB/s eta 0:00:03
#      ----                                     1.4/12.8 MB 5.4 MB/s eta 0:00:03
#      ------                                   2.1/12.8 MB 6.6 MB/s eta 0:00:02
#      --------                                 2.7/12.8 MB 7.6 MB/s eta 0:00:02
#      ----------                               3.4/12.8 MB 8.4 MB/s eta 0:00:02
#      ------------                             4.0/12.8 MB 8.9 MB/s eta 0:00:01
#      --------------                           4.8/12.8 MB 9.5 MB/s eta 0:00:01
#      ----------------                         5.2/12.8 MB 9.5 MB/s eta 0:00:01
#      -----------------                        5.6/12.8 MB 9.4 MB/s eta 0:00:01
#      ------------------                       6.0/12.8 MB 9.2 MB/s eta 0:00:01
#      --------------------                     6.5/12.8 MB 9.4 MB/s eta 0:00:01
#      ---------------------                    6.9/12.8 MB 9.4 MB/s eta 0:00:01
#      -----------------------                  7.5/12.8 MB 9.5 MB/s eta 0:00:01
#      -------------------------                8.0/12.8 MB 9.6 MB/s eta 0:00:01
#      --------------------------               8.5/12.8 MB 9.7 MB/s eta 0:00:01
#      ----------------------------             9.0/12.8 MB 9.8 MB/s eta 0:00:01
#      ------------------------------           9.6/12.8 MB 9.9 MB/s eta 0:00:01
#      -------------------------------          10.1/12.8 MB 9.9 MB/s eta 0:00:01
#      --------------------------------        10.8/12.8 MB 11.7 MB/s eta 0:00:01
#      ----------------------------------      11.4/12.8 MB 11.7 MB/s eta 0:00:01
#      ------------------------------------    12.0/12.8 MB 11.7 MB/s eta 0:00:01
#      --------------------------------------  12.6/12.8 MB 11.7 MB/s eta 0:00:01
#      --------------------------------------  12.8/12.8 MB 11.5 MB/s eta 0:00:01
#      --------------------------------------  12.8/12.8 MB 11.5 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 10.4 MB/s eta 0:00:00
# Collecting preprocess-kgptalkie@ git+https://github.com/laxmimerit/preprocess_kgptalkie.git@96bf02872d9756f29d6cddb8aafaedcd2a39bbb4 (from -r requirements.txt (line 45))
#   Using cached preprocess_kgptalkie-0.1.3-py3-none-any.whl
# Collecting annotated-types==0.6.0 (from -r requirements.txt (line 1))
#   Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Collecting beautifulsoup4==4.12.3 (from -r requirements.txt (line 2))
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Collecting blinker==1.7.0 (from -r requirements.txt (line 3))
#   Using cached blinker-1.7.0-py3-none-any.whl (13 kB)
# Collecting blis==0.7.11 (from -r requirements.txt (line 4))
#   Downloading blis-0.7.11-cp311-cp311-win_amd64.whl (6.6 MB)
#                                               0.0/6.6 MB ? eta -:--:--
#                                               0.1/6.6 MB 2.0 MB/s eta 0:00:04
#      -                                        0.2/6.6 MB 3.0 MB/s eta 0:00:03
#      --                                       0.4/6.6 MB 3.4 MB/s eta 0:00:02
#      ----                                     0.8/6.6 MB 5.1 MB/s eta 0:00:02
#      ----------                               1.7/6.6 MB 7.9 MB/s eta 0:00:01
#      ---------------                          2.6/6.6 MB 9.9 MB/s eta 0:00:01
#      ---------------------                    3.5/6.6 MB 11.1 MB/s eta 0:00:01
#      --------------------------               4.4/6.6 MB 12.3 MB/s eta 0:00:01
#      -------------------------------          5.2/6.6 MB 12.9 MB/s eta 0:00:01
#      -------------------------------------    6.3/6.6 MB 13.8 MB/s eta 0:00:01
#      ---------------------------------------  6.6/6.6 MB 14.1 MB/s eta 0:00:01
#      ---------------------------------------- 6.6/6.6 MB 12.4 MB/s eta 0:00:00
# Collecting catalogue==2.0.10 (from -r requirements.txt (line 5))
#   Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Collecting certifi==2024.2.2 (from -r requirements.txt (line 6))
#   Using cached certifi-2024.2.2-py3-none-any.whl (163 kB)
# Collecting cffi==1.16.0 (from -r requirements.txt (line 7))
#   Downloading cffi-1.16.0-cp311-cp311-win_amd64.whl (181 kB)
#                                               0.0/181.5 kB ? eta -:--:--
#      ------------------------------------- 181.5/181.5 kB 11.4 MB/s eta 0:00:00
# Collecting charset-normalizer==3.3.2 (from -r requirements.txt (line 8))
#   Downloading charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl (99 kB)
#                                               0.0/99.9 kB ? eta -:--:--
#      ---------------------------------------- 99.9/99.9 kB 5.6 MB/s eta 0:00:00
# Collecting click==8.1.7 (from -r requirements.txt (line 9))
#   Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Collecting cloudpathlib==0.16.0 (from -r requirements.txt (line 10))
#   Using cached cloudpathlib-0.16.0-py3-none-any.whl (45 kB)
# Requirement already satisfied: colorama==0.4.6 in d:\jupyter_proj\venv\lib\site-packages (from -r requirements.txt (line 11)) (0.4.6)
# Collecting confection==0.1.4 (from -r requirements.txt (line 12))
#   Using cached confection-0.1.4-py3-none-any.whl (35 kB)
# Collecting contourpy==1.2.0 (from -r requirements.txt (line 13))
#   Downloading contourpy-1.2.0-cp311-cp311-win_amd64.whl (187 kB)
#                                               0.0/187.6 kB ? eta -:--:--
#      ------------------------------------- 187.6/187.6 kB 11.1 MB/s eta 0:00:00
# Collecting cryptography==42.0.5 (from -r requirements.txt (line 14))
#   Using cached cryptography-42.0.5-cp39-abi3-win_amd64.whl (2.9 MB)
# Collecting cssselect==1.2.0 (from -r requirements.txt (line 15))
#   Using cached cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Collecting cycler==0.12.1 (from -r requirements.txt (line 16))
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting cymem==2.0.8 (from -r requirements.txt (line 17))
#   Downloading cymem-2.0.8-cp311-cp311-win_amd64.whl (39 kB)
# Collecting et-xmlfile==1.1.0 (from -r requirements.txt (line 19))
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Collecting feedfinder2==0.0.4 (from -r requirements.txt (line 20))
#   Using cached feedfinder2-0.0.4-py3-none-any.whl
# Collecting feedparser==6.0.11 (from -r requirements.txt (line 21))
#   Using cached feedparser-6.0.11-py3-none-any.whl (81 kB)
# Collecting filelock==3.13.3 (from -r requirements.txt (line 22))
#   Using cached filelock-3.13.3-py3-none-any.whl (11 kB)
# Collecting Flask==3.0.2 (from -r requirements.txt (line 23))
#   Using cached flask-3.0.2-py3-none-any.whl (101 kB)
# Collecting Flask-Cors==4.0.0 (from -r requirements.txt (line 24))
#   Using cached Flask_Cors-4.0.0-py2.py3-none-any.whl (14 kB)
# Collecting fonttools==4.50.0 (from -r requirements.txt (line 25))
#   Downloading fonttools-4.50.0-cp311-cp311-win_amd64.whl (2.2 MB)
#                                               0.0/2.2 MB ? eta -:--:--
#      -----------                              0.7/2.2 MB 13.7 MB/s eta 0:00:01
#      -------------------                      1.0/2.2 MB 16.4 MB/s eta 0:00:01
#      -------------------                      1.0/2.2 MB 16.4 MB/s eta 0:00:01
#      -------------------                      1.0/2.2 MB 16.4 MB/s eta 0:00:01
#      -------------------                      1.0/2.2 MB 16.4 MB/s eta 0:00:01
#      -----------------------------            1.6/2.2 MB 5.9 MB/s eta 0:00:01
#      ---------------------------------------  2.2/2.2 MB 6.9 MB/s eta 0:00:01
#      ---------------------------------------- 2.2/2.2 MB 6.3 MB/s eta 0:00:00
# Collecting idna==3.6 (from -r requirements.txt (line 26))
#   Using cached idna-3.6-py3-none-any.whl (61 kB)
# Collecting install==1.3.5 (from -r requirements.txt (line 27))
#   Using cached install-1.3.5-py3-none-any.whl (3.2 kB)
# Collecting itsdangerous==2.1.2 (from -r requirements.txt (line 28))
#   Using cached itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting jieba3k==0.35.1 (from -r requirements.txt (line 29))
#   Using cached jieba3k-0.35.1-py3-none-any.whl
# Collecting Jinja2==3.1.3 (from -r requirements.txt (line 30))
#   Using cached Jinja2-3.1.3-py3-none-any.whl (133 kB)
# Collecting joblib==1.3.2 (from -r requirements.txt (line 31))
#   Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Collecting kiwisolver==1.4.5 (from -r requirements.txt (line 32))
#   Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl (56 kB)
#                                               0.0/56.1 kB ? eta -:--:--
#      ---------------------------------------- 56.1/56.1 kB ? eta 0:00:00
# Collecting langcodes==3.3.0 (from -r requirements.txt (line 33))
#   Using cached langcodes-3.3.0-py3-none-any.whl (181 kB)
# Collecting lxml==5.2.0 (from -r requirements.txt (line 34))
#   Downloading lxml-5.2.0-cp311-cp311-win_amd64.whl (3.8 MB)
#                                               0.0/3.8 MB ? eta -:--:--
#      --------                                 0.8/3.8 MB 16.8 MB/s eta 0:00:01
#      ----------------                         1.6/3.8 MB 16.7 MB/s eta 0:00:01
#      ------------------------                 2.3/3.8 MB 18.5 MB/s eta 0:00:01
#      ------------------------------           2.9/3.8 MB 15.5 MB/s eta 0:00:01
#      -------------------------------------    3.6/3.8 MB 15.4 MB/s eta 0:00:01
#      ---------------------------------------  3.8/3.8 MB 15.2 MB/s eta 0:00:01
#      ---------------------------------------- 3.8/3.8 MB 12.2 MB/s eta 0:00:00
# Collecting MarkupSafe==2.1.5 (from -r requirements.txt (line 35))
#   Downloading MarkupSafe-2.1.5-cp311-cp311-win_amd64.whl (17 kB)
# Collecting matplotlib==3.8.3 (from -r requirements.txt (line 36))
#   Downloading matplotlib-3.8.3-cp311-cp311-win_amd64.whl (7.6 MB)
#                                               0.0/7.6 MB ? eta -:--:--
#      ----                                     0.8/7.6 MB 16.8 MB/s eta 0:00:01
#      -------                                  1.5/7.6 MB 19.1 MB/s eta 0:00:01
#      -----------                              2.3/7.6 MB 17.9 MB/s eta 0:00:01
#      ---------------                          2.9/7.6 MB 15.5 MB/s eta 0:00:01
#      ------------------                       3.5/7.6 MB 15.9 MB/s eta 0:00:01
#      ----------------------                   4.2/7.6 MB 15.8 MB/s eta 0:00:01
#      -------------------------                4.9/7.6 MB 15.5 MB/s eta 0:00:01
#      ----------------------------             5.5/7.6 MB 14.7 MB/s eta 0:00:01
#      --------------------------------         6.2/7.6 MB 15.3 MB/s eta 0:00:01
#      ------------------------------------     6.9/7.6 MB 15.2 MB/s eta 0:00:01
#      ---------------------------------------  7.5/7.6 MB 15.1 MB/s eta 0:00:01
#      ---------------------------------------  7.6/7.6 MB 14.8 MB/s eta 0:00:01
#      ---------------------------------------- 7.6/7.6 MB 12.9 MB/s eta 0:00:00
# Collecting murmurhash==1.0.10 (from -r requirements.txt (line 37))
#   Downloading murmurhash-1.0.10-cp311-cp311-win_amd64.whl (25 kB)
# Collecting newspaper3k==0.2.8 (from -r requirements.txt (line 38))
#   Using cached newspaper3k-0.2.8-py3-none-any.whl (211 kB)
# Collecting nltk==3.8.1 (from -r requirements.txt (line 39))
#   Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Collecting numpy==1.26.4 (from -r requirements.txt (line 40))
#   Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
#                                               0.0/15.8 MB ? eta -:--:--
#      --                                       1.0/15.8 MB 31.7 MB/s eta 0:00:01
#      -----                                    2.0/15.8 MB 25.6 MB/s eta 0:00:01
#      -------                                  2.8/15.8 MB 22.4 MB/s eta 0:00:01
#      ---------                                3.7/15.8 MB 21.4 MB/s eta 0:00:01
#      -----------                              4.6/15.8 MB 21.0 MB/s eta 0:00:01
#      -------------                            5.5/15.8 MB 20.7 MB/s eta 0:00:01
#      ----------------                         6.6/15.8 MB 21.2 MB/s eta 0:00:01
#      -------------------                      7.7/15.8 MB 21.5 MB/s eta 0:00:01
#      ----------------------                   8.9/15.8 MB 21.8 MB/s eta 0:00:01
#      ------------------------                10.0/15.8 MB 21.9 MB/s eta 0:00:01
#      ---------------------------             11.1/15.8 MB 21.8 MB/s eta 0:00:01
#      -----------------------------           12.1/15.8 MB 21.9 MB/s eta 0:00:01
#      --------------------------------        13.1/15.8 MB 21.9 MB/s eta 0:00:01
#      -----------------------------------     14.2/15.8 MB 22.6 MB/s eta 0:00:01
#      -------------------------------------   15.2/15.8 MB 22.6 MB/s eta 0:00:01
#      --------------------------------------  15.8/15.8 MB 22.6 MB/s eta 0:00:01
#      --------------------------------------  15.8/15.8 MB 22.6 MB/s eta 0:00:01
#      --------------------------------------- 15.8/15.8 MB 18.7 MB/s eta 0:00:00
# Collecting openpyxl==3.1.2 (from -r requirements.txt (line 41))
#   Using cached openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
# Requirement already satisfied: packaging==24.0 in d:\jupyter_proj\venv\lib\site-packages (from -r requirements.txt (line 42)) (24.0)
# Collecting pandas==2.2.1 (from -r requirements.txt (line 43))
#   Downloading pandas-2.2.1-cp311-cp311-win_amd64.whl (11.6 MB)
#                                               0.0/11.6 MB ? eta -:--:--
#      ---                                      0.9/11.6 MB 27.7 MB/s eta 0:00:01
#      ------                                   1.8/11.6 MB 23.5 MB/s eta 0:00:01
#      ---------                                2.8/11.6 MB 25.6 MB/s eta 0:00:01
#      --------------                           4.2/11.6 MB 24.2 MB/s eta 0:00:01
#      ------------------                       5.4/11.6 MB 23.2 MB/s eta 0:00:01
#      ----------------------                   6.6/11.6 MB 23.3 MB/s eta 0:00:01
#      --------------------------               7.6/11.6 MB 23.1 MB/s eta 0:00:01
#      -----------------------------            8.4/11.6 MB 23.4 MB/s eta 0:00:01
#      ---------------------------------        9.6/11.6 MB 22.8 MB/s eta 0:00:01
#      ---------------------------------        9.8/11.6 MB 22.3 MB/s eta 0:00:01
#      ---------------------------------        9.8/11.6 MB 22.3 MB/s eta 0:00:01
#      --------------------------------------  11.4/11.6 MB 19.8 MB/s eta 0:00:01
#      --------------------------------------  11.6/11.6 MB 20.5 MB/s eta 0:00:01
#      --------------------------------------  11.6/11.6 MB 20.5 MB/s eta 0:00:01
#      --------------------------------------- 11.6/11.6 MB 16.0 MB/s eta 0:00:00
# Collecting pillow==10.2.0 (from -r requirements.txt (line 44))
#   Downloading pillow-10.2.0-cp311-cp311-win_amd64.whl (2.6 MB)
#                                               0.0/2.6 MB ? eta -:--:--
#      -----------                              0.7/2.6 MB 23.1 MB/s eta 0:00:01
#      ---------------------------              1.8/2.6 MB 23.0 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 MB 20.8 MB/s eta 0:00:01
#      ---------------------------------------- 2.6/2.6 MB 16.7 MB/s eta 0:00:00
# Collecting preshed==3.0.9 (from -r requirements.txt (line 46))
#   Downloading preshed-3.0.9-cp311-cp311-win_amd64.whl (122 kB)
#                                               0.0/122.3 kB ? eta -:--:--
#      -------------------------------------- 122.3/122.3 kB 7.5 MB/s eta 0:00:00
# Collecting pycparser==2.22 (from -r requirements.txt (line 47))
#   Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Collecting pydantic==2.6.4 (from -r requirements.txt (line 48))
#   Using cached pydantic-2.6.4-py3-none-any.whl (394 kB)
# Collecting pydantic_core==2.16.3 (from -r requirements.txt (line 49))
#   Downloading pydantic_core-2.16.3-cp311-none-win_amd64.whl (1.9 MB)
#                                               0.0/1.9 MB ? eta -:--:--
#      ------------------                       0.9/1.9 MB 18.3 MB/s eta 0:00:01
#      ---------------------------------------  1.8/1.9 MB 19.5 MB/s eta 0:00:01
#      ---------------------------------------- 1.9/1.9 MB 15.0 MB/s eta 0:00:00
# Collecting PyMySQL==1.1.0 (from -r requirements.txt (line 50))
#   Using cached PyMySQL-1.1.0-py3-none-any.whl (44 kB)
# Collecting pyparsing==3.1.2 (from -r requirements.txt (line 51))
#   Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Collecting python-crfsuite==0.9.10 (from -r requirements.txt (line 52))
#   Downloading python_crfsuite-0.9.10-cp311-cp311-win_amd64.whl (155 kB)
#                                               0.0/155.8 kB ? eta -:--:--
#      -------------------------------------- 155.8/155.8 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil==2.9.0.post0 in d:\jupyter_proj\venv\lib\site-packages (from -r requirements.txt (line 53)) (2.9.0.post0)
# Collecting pytz==2024.1 (from -r requirements.txt (line 54))
#   Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Collecting PyYAML==6.0.1 (from -r requirements.txt (line 55))
#   Downloading PyYAML-6.0.1-cp311-cp311-win_amd64.whl (144 kB)
#                                               0.0/144.7 kB ? eta -:--:--
#      -------------------------------------- 144.7/144.7 kB 8.4 MB/s eta 0:00:00
# Collecting regex==2023.12.25 (from -r requirements.txt (line 56))
#   Downloading regex-2023.12.25-cp311-cp311-win_amd64.whl (269 kB)
#                                               0.0/269.5 kB ? eta -:--:--
#      ------------------------------------- 269.5/269.5 kB 17.3 MB/s eta 0:00:00
# Collecting requests==2.31.0 (from -r requirements.txt (line 57))
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting requests-file==2.0.0 (from -r requirements.txt (line 58))
#   Using cached requests_file-2.0.0-py2.py3-none-any.whl (4.2 kB)
# Collecting scikit-learn==1.4.1.post1 (from -r requirements.txt (line 59))
#   Downloading scikit_learn-1.4.1.post1-cp311-cp311-win_amd64.whl (10.6 MB)
#                                               0.0/10.6 MB ? eta -:--:--
#      -------------------------------         37.6/46.2 MB 18.2 MB/s eta 0:00:01
#      --------------------------------        38.3/46.2 MB 16.8 MB/s eta 0:00:01
#      --------------------------------        38.9/46.2 MB 16.4 MB/s eta 0:00:01
#      ---------------------------------       39.5/46.2 MB 16.0 MB/s eta 0:00:01
#      ----------------------------------      40.4/46.2 MB 14.9 MB/s eta 0:00:01
#      ----------------------------------      41.0/46.2 MB 14.9 MB/s eta 0:00:01
#      -----------------------------------     41.7/46.2 MB 15.2 MB/s eta 0:00:01
#      -----------------------------------     42.4/46.2 MB 14.9 MB/s eta 0:00:01
#      ------------------------------------    42.9/46.2 MB 14.6 MB/s eta 0:00:01
#      ------------------------------------    43.5/46.2 MB 14.9 MB/s eta 0:00:01
#      -------------------------------------   44.2/46.2 MB 14.9 MB/s eta 0:00:01
#      -------------------------------------   44.8/46.2 MB 14.6 MB/s eta 0:00:01
#      --------------------------------------  45.6/46.2 MB 14.6 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  46.2/46.2 MB 14.2 MB/s eta 0:00:01
#      ---------------------------------------- 46.2/46.2 MB 1.8 MB/s eta 0:00:00
# Collecting sgmllib3k==1.0.0 (from -r requirements.txt (line 61))
#   Using cached sgmllib3k-1.0.0-py3-none-any.whl
# Requirement already satisfied: six==1.16.0 in d:\jupyter_proj\venv\lib\site-packages (from -r requirements.txt (line 62)) (1.16.0)
# Collecting smart-open==6.4.0 (from -r requirements.txt (line 63))
#   Using cached smart_open-6.4.0-py3-none-any.whl (57 kB)
# Collecting soupsieve==2.5 (from -r requirements.txt (line 64))
#   Using cached soupsieve-2.5-py3-none-any.whl (36 kB)
# Collecting spacy==3.7.4 (from -r requirements.txt (line 65))
#   Downloading spacy-3.7.4-cp311-cp311-win_amd64.whl (12.1 MB)
#                                               0.0/12.1 MB ? eta -:--:--
#      --                                       0.7/12.1 MB 23.8 MB/s eta 0:00:01
#      -----                                    1.7/12.1 MB 21.7 MB/s eta 0:00:01
#      ---------                                2.8/12.1 MB 20.3 MB/s eta 0:00:01
#      ------------                             3.8/12.1 MB 20.0 MB/s eta 0:00:01
#      ---------------                          4.7/12.1 MB 20.0 MB/s eta 0:00:01
#      ------------------                       5.6/12.1 MB 20.0 MB/s eta 0:00:01
#      ---------------------                    6.4/12.1 MB 19.4 MB/s eta 0:00:01
#      ------------------------                 7.3/12.1 MB 19.4 MB/s eta 0:00:01
#      --------------------------               8.0/12.1 MB 18.9 MB/s eta 0:00:01
#      ----------------------------             8.7/12.1 MB 18.5 MB/s eta 0:00:01
#      ------------------------------           9.3/12.1 MB 18.1 MB/s eta 0:00:01
#      --------------------------------        10.0/12.1 MB 17.9 MB/s eta 0:00:01
#      -----------------------------------     10.8/12.1 MB 17.7 MB/s eta 0:00:01
#      -------------------------------------   11.7/12.1 MB 17.7 MB/s eta 0:00:01
#      --------------------------------------  12.1/12.1 MB 17.2 MB/s eta 0:00:01
#      --------------------------------------  12.1/12.1 MB 17.2 MB/s eta 0:00:01
#      --------------------------------------- 12.1/12.1 MB 14.5 MB/s eta 0:00:00
# Collecting spacy-legacy==3.0.12 (from -r requirements.txt (line 66))
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting spacy-loggers==1.0.5 (from -r requirements.txt (line 67))
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Collecting srsly==2.4.8 (from -r requirements.txt (line 68))
#   Downloading srsly-2.4.8-cp311-cp311-win_amd64.whl (479 kB)
#                                               0.0/479.7 kB ? eta -:--:--
#      ------------------------------------- 479.7/479.7 kB 15.1 MB/s eta 0:00:00
# Collecting textblob==0.18.0.post0 (from -r requirements.txt (line 69))
#   Using cached textblob-0.18.0.post0-py3-none-any.whl (626 kB)
# Collecting thinc==8.2.3 (from -r requirements.txt (line 70))
#   Downloading thinc-8.2.3-cp311-cp311-win_amd64.whl (1.5 MB)
#                                               0.0/1.5 MB ? eta -:--:--
#      --------------                           0.5/1.5 MB 16.8 MB/s eta 0:00:01
#      ----------------------------------       1.3/1.5 MB 16.1 MB/s eta 0:00:01
#      ---------------------------------------- 1.5/1.5 MB 13.5 MB/s eta 0:00:00
# Collecting threadpoolctl==3.4.0 (from -r requirements.txt (line 71))
#   Using cached threadpoolctl-3.4.0-py3-none-any.whl (17 kB)
# Collecting tinysegmenter==0.3 (from -r requirements.txt (line 72))
#   Using cached tinysegmenter-0.3-py3-none-any.whl
# Collecting tldextract==5.1.2 (from -r requirements.txt (line 73))
#   Using cached tldextract-5.1.2-py3-none-any.whl (97 kB)
# Collecting tqdm==4.66.2 (from -r requirements.txt (line 74))
#   Using cached tqdm-4.66.2-py3-none-any.whl (78 kB)
# Collecting typer==0.9.4 (from -r requirements.txt (line 75))
#   Using cached typer-0.9.4-py3-none-any.whl (45 kB)
# Collecting typing_extensions==4.10.0 (from -r requirements.txt (line 76))
#   Using cached typing_extensions-4.10.0-py3-none-any.whl (33 kB)
# Collecting tzdata==2024.1 (from -r requirements.txt (line 77))
#   Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Collecting underthesea==6.8.0 (from -r requirements.txt (line 78))
#   Using cached underthesea-6.8.0-py3-none-any.whl (20.9 MB)
# Collecting underthesea_core==1.0.4 (from -r requirements.txt (line 79))
#   Downloading underthesea_core-1.0.4-cp311-none-win_amd64.whl (552 kB)
#                                               0.0/553.0 kB ? eta -:--:--
#      ------------------------------------- 553.0/553.0 kB 11.5 MB/s eta 0:00:00
# Collecting urllib3==2.2.1 (from -r requirements.txt (line 80))
#   Using cached urllib3-2.2.1-py3-none-any.whl (121 kB)
# Collecting wasabi==1.1.2 (from -r requirements.txt (line 81))
#   Using cached wasabi-1.1.2-py3-none-any.whl (27 kB)
# Collecting weasel==0.3.4 (from -r requirements.txt (line 82))
#   Using cached weasel-0.3.4-py3-none-any.whl (50 kB)
# Collecting Werkzeug==3.0.2 (from -r requirements.txt (line 83))
#   Using cached werkzeug-3.0.2-py3-none-any.whl (226 kB)
# Requirement already satisfied: setuptools in d:\jupyter_proj\venv\lib\site-packages (from spacy==3.7.4->-r requirements.txt (line 65)) (65.5.0)
# Installing collected packages: underthesea_core, tinysegmenter, sgmllib3k, pytz, python-crfsuite, jieba3k, cymem, wasabi, urllib3, tzdata, typing_extensions, tqdm, threadpoolctl, spacy-loggers, spacy-legacy, soupsieve, smart-open, regex, PyYAML, pyparsing, PyMySQL, pycparser, preprocess-kgptalkie, pillow, numpy, murmurhash, MarkupSafe, lxml, langcodes, kiwisolver, joblib, itsdangerous, install, idna, fonttools, filelock, feedparser, et-xmlfile, cycler, cssselect, cloudpathlib, click, charset-normalizer, certifi, catalogue, blinker, annotated-types, Werkzeug, typer, srsly, scipy, requests, pydantic_core, preshed, pandas, openpyxl, nltk, Jinja2, contourpy, cffi, blis, beautifulsoup4, textblob, scikit-learn, requests-file, pydantic, matplotlib, Flask, feedfinder2, cryptography, underthesea, tldextract, Flask-Cors, confection, weasel, thinc, newspaper3k, spacy, en-core-web-sm
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.12.0
#     Uninstalling typing_extensions-4.12.0:
#       Successfully uninstalled typing_extensions-4.12.0
# Successfully installed Flask-3.0.2 Flask-Cors-4.0.0 Jinja2-3.1.3 MarkupSafe-2.1.5 PyMySQL-1.1.0 PyYAML-6.0.1 Werkzeug-3.0.2 annotated-types-0.6.0 beautifulsoup4-4.12.3 blinker-1.7.0 blis-0.7.11 catalogue-2.0.10 certifi-2024.2.2 cffi-1.16.0 charset-normalizer-3.3.2 click-8.1.7 cloudpathlib-0.16.0 confection-0.1.4 contourpy-1.2.0 cryptography-42.0.5 cssselect-1.2.0 cycler-0.12.1 cymem-2.0.8 en-core-web-sm-3.7.1 et-xmlfile-1.1.0 feedfinder2-0.0.4 feedparser-6.0.11 filelock-3.13.3 fonttools-4.50.0 idna-3.6 install-1.3.5 itsdangerous-2.1.2 jieba3k-0.35.1 joblib-1.3.2 kiwisolver-1.4.5 langcodes-3.3.0 lxml-5.2.0 matplotlib-3.8.3 murmurhash-1.0.10 newspaper3k-0.2.8 nltk-3.8.1 numpy-1.26.4 openpyxl-3.1.2 pandas-2.2.1 pillow-10.2.0 preprocess-kgptalkie-0.1.3 preshed-3.0.9 pycparser-2.22 pydantic-2.6.4 pydantic_core-2.16.3 pyparsing-3.1.2 python-crfsuite-0.9.10 pytz-2024.1 regex-2023.12.25 requests-2.31.0 requests-file-2.0.0 scikit-learn-1.4.1.post1 scipy-1.12.0 sgmllib3k-1.0.0 smart-open-6.4.0 soupsieve-2.5 spacy-3.7.4 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 textblob-0.18.0.post0 thinc-8.2.3 threadpoolctl-3.4.0 tinysegmenter-0.3 tldextract-5.1.2 tqdm-4.66.2 typer-0.9.4 typing_extensions-4.10.0 tzdata-2024.1 underthesea-6.8.0 underthesea_core-1.0.4 urllib3-2.2.1 wasabi-1.1.2 weasel-0.3.4
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: D:\jupyter_proj\venv\Scripts\python.exe -m pip install --upgrade pip

# %%
import asyncio
import base64
import decimal
import json
from datetime import datetime, date

import flask
# import pymysql
import requests
from flask import Flask, render_template, request
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import LinearSVC
from sklearn import tree
from sklearn.metrics import accuracy_score, classification_report
import openpyxl
import pandas as pd
import numpy as np
import preprocess_kgptalkie as ps
import re
from flask_cors import CORS
import glob
import os
from underthesea import sentiment, pos_tag, word_tokenize
from flask import g
from sklearn.pipeline import Pipeline
import underthesea
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier


SIZE_DEMO = 100000


def get_clean(x):
    x = str(x).lower().replace('\\', '').replace('_', ' ')
    x = ps.cont_exp(x)
    x = ps.remove_emails(x)
    x = ps.remove_urls(x)
    x = ps.remove_html_tags(x)
    # x = ps.remove_accented_chars(x)
    x = ps.remove_special_chars(x)
    x = re.sub("(.)\\1{2,}", "\\1", x)
    return x

existing_file = 'Book2.csv'
df = pd.read_csv(existing_file)
# df['Review'] = df['Review'].apply(lambda x: get_clean(x))

# total_files = len(df)
# train_size = int(0.6 * total_files)
# val_size = int(0.2 * total_files)
# test_size = total_files - train_size - val_size

# train_files = df[:train_size]
# val_files = df[train_size:train_size + val_size]
# test_files = df[train_size + val_size:]


train_texts, test_texts, train_labels, test_labels = train_test_split(df['Review'], df['Sentiment'], test_size=0.2, random_state=0)

train_texts, val_texts, train_labels, val_labels = train_test_split(train_texts, train_labels, test_size=0.25, random_state=0)


def preprocess(docs):
    return [underthesea.word_tokenize(doc.lower()) for doc in docs]


def get_vocabularies(tokenized_docs):
    vocabs = set()
    for doc in tokenized_docs:
        vocabs.update(doc)
    return vocabs

def identity_tokenizer(text):
    return text

# def create_vector(tokenized_docs):
    

tokenized_docs = preprocess(train_texts[:SIZE_DEMO].astype('U'))
tokenized_docs_val = preprocess(val_texts[:SIZE_DEMO].astype('U'))
tokenized_docs_test = preprocess(test_texts[:SIZE_DEMO].astype('U'))
# vocabs = get_vocabularies(tokenized_docs)
# print(vocabs)
    
        


tfidf = TfidfVectorizer(analyzer="word", tokenizer=identity_tokenizer, token_pattern=None, lowercase=False)
# print(tokenized_docs[:100])
X_train = tfidf.fit_transform(tokenized_docs)
# print(X_train)
X_train.shape
y_train = train_labels[:SIZE_DEMO]
# X_train, self.X_test, self.y_train, self.y_test = train_test_split(self.X, self.y, test_size=0.2,
#                                                                                 random_state=0)
clf = LinearSVC().fit(X_train, y_train)
# clf = tree.DecisionTreeClassifier().fit(X_train, y_train)
# clf = MultinomialNB().fit(X_train, y_train)
# clf = RandomForestClassifier().fit(X_train, y_train)



X_val = tfidf.transform(tokenized_docs_val)

val_predictions = clf.predict(X_val)
val_accuracy = accuracy_score(val_labels[:SIZE_DEMO], val_predictions)
print(f"Validation Accuracy: {val_accuracy:.4f}")
print(classification_report(val_labels[:SIZE_DEMO], val_predictions))

# docs_new = ['God is love', 'OpenGL on the GPU is fast']
# X_new_tfidf = tfidf.transform(docs_new)

# y_pred = clf.predict(X_new_tfidf)

# for doc, category in zip(docs_new, y_pred):
#     print('%r => %s' % (doc, category))
    
# X_new_tfidf = tfidf.transform(test_texts)

# predicted = clf.predict(X_new_tfidf)

# np.mean(predicted == test_labels)

param_grid = {
    'C': [0.1, 1, 10, 100, 1000],
    'max_iter': [1000, 5000, 10000],
}

# tree_param = {'criterion':['gini','entropy'],'max_depth':[4,5,6,7,8,9,10,11,12,15,20,30,40,50,70,90,120,150]}

# parameters = {  
#     'alpha': (1, 0.1, 0.01, 0.001, 0.0001, 0.00001)  
# }  

# parameters = {  
#     'max_depth':[3,5,10,None],
#               'n_estimators':[10,100,200],
#               'max_features':[1,3,5,7],
#               'min_samples_leaf':[1,2,3],
#               'min_samples_split':[1,2,3]
# }  


# Initialize GridSearchCV
grid_search = GridSearchCV(LinearSVC(), param_grid, cv=3, refit = True, scoring='accuracy')

# grid_search = GridSearchCV(tree.DecisionTreeClassifier(), tree_param, cv=3, refit = True, scoring='accuracy')

# grid_search = GridSearchCV(MultinomialNB(), parameters, cv=3, refit = True, scoring='accuracy')

# grid_search = GridSearchCV(RandomForestClassifier(), parameters, cv=3, refit = True, scoring='accuracy')

# Fit the grid search
grid_search.fit(X_train, train_labels[:SIZE_DEMO])

# Best parameters
best_params = grid_search.best_params_
print(f"Best Parameters: {best_params}")

# Evaluate best model on validation set
best_model = grid_search.best_estimator_
val_predictions = best_model.predict(X_val)
val_accuracy = accuracy_score(val_labels[:SIZE_DEMO], val_predictions)
print(f"Validation Accuracy with Best Model: {val_accuracy:.4f}")
print(classification_report(val_labels[:SIZE_DEMO], val_predictions))
# Out:
# D:\jupyter_proj\venv\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# Validation Accuracy: 0.8434
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85      6862
#      neutral       0.69      0.63      0.66       444
#     positive       0.84      0.85      0.85      7357
#
#     accuracy                           0.84     14663
#    macro avg       0.80      0.78      0.79     14663
# weighted avg       0.84      0.84      0.84     14663
# D:\jupyter_proj\venv\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# D:\jupyter_proj\venv\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# D:\jupyter_proj\venv\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# D:\jupyter_proj\venv\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# D:\jupyter_proj\venv\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# D:\jupyter_proj\venv\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# D:\jupyter_proj\venv\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# D:\jupyter_proj\venv\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# D:\jupyter_proj\venv\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# D:\jupyter_proj\venv\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# D:\jupyter_proj\venv\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# D:\jupyter_proj\venv\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# D:\jupyter_proj\venv\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# D:\jupyter_proj\venv\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# D:\jupyter_proj\venv\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# D:\jupyter_proj\venv\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# D:\jupyter_proj\venv\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# D:\jupyter_proj\venv\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# D:\jupyter_proj\venv\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# D:\jupyter_proj\venv\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# D:\jupyter_proj\venv\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# D:\jupyter_proj\venv\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# Best Parameters: {'C': 1}
# Validation Accuracy with Best Model: 0.8434
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85      6862
#      neutral       0.69      0.63      0.66       444
#     positive       0.84      0.85      0.85      7357
#
#     accuracy                           0.84     14663
#    macro avg       0.80      0.78      0.79     14663
# weighted avg       0.84      0.84      0.84     14663
